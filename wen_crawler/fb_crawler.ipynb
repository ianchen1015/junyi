# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
from time import sleep

# %%
url = 'https://www.facebook.com/groups/247170855413829/files/'
usr = "@gmail.com"
pwd = ""

#driver.quit()
driver = webdriver.Chrome(executable_path=r'./chromedriver')

def login():
    driver.get('https://www.facebook.com/')
    print ("Opened facebook")
    sleep(1)

    username_box = driver.find_element_by_id('email')
    username_box.send_keys(usr)
    print ("Email Id entered")
    sleep(1)

    password_box = driver.find_element_by_id('pass')
    password_box.send_keys(pwd)
    print ("Password entered")

    login_box = driver.find_element_by_id('loginbutton')
    login_box.click()

    print ("Login Done\n")

login()
driver.get(url)
sleep(3)
# Out:
# Opened facebook
# Email Id entered
# Password entered
# Login Done

# %%
cnt = 1
while True:
    try:
        load_more_btn = driver.find_elements_by_xpath('//a[@class="pam uiBoxLightblue uiMorePagerPrimary"]')[0]
        load_more_btn.click()
        sleep(5)
        print(cnt)
        cnt += 1
    except:
        break


print("Finished")

# %%
pageSource = driver.page_source

soup = BeautifulSoup(pageSource, "html5lib")
li_lst = soup.findAll('li',{'class':'_pu_'})

col = ['file_name','post_link','user_name','user_link','upload_time']
df = pd.DataFrame(columns=col)

#li = li_lst[0]
for li in li_lst:
    li_a = li.findAll('a')

    # title
    a_title = li_a[0]
    file_name = a_title.get_text().split('.')[0]
    post_link = 'https://www.facebook.com' + a_title['href']

    # user
    a_user = li_a[1]
    user_name = a_user.get_text()
    user_link = a_user['href'].split('fref')[0]

    # time
    a_time = li_a[2]
    upload_time = a_time.get_text()

    print('{}\n{}\n{}\n{}\n{}\n'.format(file_name, post_link, user_name, user_link, upload_time))
    #print(file_name)

    df = df.append({'file_name':file_name,
                    'post_link':post_link,
                    'user_name':user_name,
                    'user_link':user_link,
                    'upload_time':upload_time
                    },ignore_index=True)
df.to_csv('fb_crawler_output.csv', index=False)
df.head()
# Out:
# 履歷自傳小書小檔案--接新班_請孩子介紹自己給你吧!
# https://www.facebook.com/groups/247170855413829/667055370092040/
# 彭遠芬
# https://www.facebook.com/yuanfen.peng?
# 2015年8月23日下午6:15
#
# 康軒二上(一~四課)
# https://www.facebook.com/groups/247170855413829/667052746758969/
# 黃小綠
# https://www.facebook.com/profile.php?id=100007072876779&
# 2015年8月23日下午5:51
#
# 二上第01課狗蟻備課
# https://www.facebook.com/groups/247170855413829/667008333430077/
# 謝千千
# https://www.facebook.com/chienhuj?
# 2015年8月23日下午1:56
#
# 一上第01課來去讀冊備課
# https://www.facebook.com/groups/247170855413829/667003186763925/
# 謝千千
# https://www.facebook.com/chienhuj?
# 2015年8月23日下午1:34
#
# 六上第01課叫出我的名臺灣備課
# https://www.facebook.com/groups/247170855413829/666996570097920/
# 謝千千
# https://www.facebook.com/chienhuj?
# 2015年8月23日下午1:08
#
# 心_日記
# https://www.facebook.com/groups/247170855413829/666286806835563/
# 張紹恆
# https://www.facebook.com/hai760109?
# 2015年8月21日下午11:52
#
# 溫老師彭老師金門分享筆記
# https://www.facebook.com/groups/247170855413829/666257193505191/
# Wan Chen Hung
# https://www.facebook.com/wanchen.hung.50?
# 2015年8月21日下午10:00
#
# 段老師8
# https://www.facebook.com/groups/247170855413829/666241360173441/
# 劉瓊華
